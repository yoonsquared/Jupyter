# %% [markdown]
# # The First Jupyter File
# ## Hello World.

# %% [markdown]
# The file will contain some practices regarding python codes, equation writing, visualization and more.

# %% [markdown]
# ## Code

# %%
print ("hello world")
# Out:
# hello world

# %% [markdown]
# adds two parameters

# %%
def add(a,b):
    return a+b

# %%
add(3,5)
# Out:
# 8

# %% [markdown]
# ## Equation

# %% [markdown]
# $\sqrt(X^2+Y^2+Z^2)$

# %% [markdown]
# more examples -> https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Typesetting%20Equations.html

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Image

# %%
from IPython.display import Image
Image(url="https://cdn-images-1.medium.com/max/1600/1*LPnY8nOLg4S6_TG0DEXwsg.png")
# Out:
# <img src="https://cdn-images-1.medium.com/max/1600/1*LPnY8nOLg4S6_TG0DEXwsg.png"/>

# %% [markdown]
# ### Video

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("SLPo0o_HArs")

# %% [markdown]
# ### chart

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('result')
plt.show()

# %% [markdown]
# ## Performance Check

# %%
# %timeit 3+4
# Out:
# 23.8 ns ± 0.511 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %timeit add(3,4)
# Out:
# 154 ns ± 3.61 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
